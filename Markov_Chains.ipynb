# %%
import random
from collections import defaultdict

def build_markov_chain(sample_text: str, chain_length: int) -> dict:
    # Check if sample text is empty
    if not sample_text.strip():
        raise ValueError("Sample text is empty. Cannot build Markov chain.")

    # Tokenize sample text into words
    words = sample_text.split()

    # Build Markov chain dictionary using defaultdict
    markov_chain = defaultdict(list)
    for i in range(len(words) - chain_length):
        key = tuple(words[i:i + chain_length])
        value = words[i + chain_length]
        markov_chain[key].append(value)

    return markov_chain

def generate_sentence(markov_chain: dict, start_words: list[str], num_generated: int) -> str:
    # Generate sentence
    current_words = tuple(start_words)
    generated_sentence = list(current_words)
    while len(generated_sentence) < num_generated:
        next_word = random.choice(markov_chain.get(current_words, ['<end>']))
        if next_word == '<end>':
            break
        generated_sentence.append(next_word)
        current_words = tuple(generated_sentence[-len(current_words):])

    return ' '.join(generated_sentence)

def print_markov_chain(markov_chain: dict, chain_length: int):
    # Print Markov chain dictionary
    print(f"Markov Chain Dictionary (Chain Length: {chain_length}):")
    for key, value in markov_chain.items():
        print(f"{key} -> {value}")

def main():
    # Sample text excerpt
    sample_text = """
    Alice, a young girl, sits bored by a riverbank and spots a White Rabbit with a pocket watch and waistcoat lamenting that he is late. Surprised, Alice follows him down a rabbit hole, which sends her into a lengthy plummet but to a safe landing. Inside a room with a table, she finds a key to a tiny door, beyond which is a garden. While pondering how to fit through the door, she discovers a bottle labelled "Drink me". Alice drinks some of the bottle's contents, and to her astonishment, she shrinks small enough to enter the door. However, she had left the key upon the table and cannot reach it. Alice then discovers and eats a cake labelled "Eat me", which causes her to grow to a tremendous size. Unhappy, Alice bursts into tears, and the passing White Rabbit flees in a panic, dropping a fan and two gloves. Alice uses the fan for herself, which causes her to shrink once more and leaves her swimming in a pool of her own tears. Within the pool, Alice meets various animals and birds, who convene on a bank and engage in a "Caucus Race" to dry themselves. Following the end of the race, Alice inadvertently frightens the animals away by discussing her cat.
    """

    # Test case 1: Single start word at the beginning, and varying chain lengths
    start_word1 = ['Alice']
    chain_lengths1 = [2, 3, 4]
    num_generated1 = 20

    # Test case 2: Start words in the middle, and varying chain lengths
    start_words2 = ['White', 'Rabbit']
    chain_lengths2 = [2, 3, 4]
    num_generated2 = 20

    # Test case 3: Empty sample text
    empty_sample_text = ""

    # Convert start words to tuple for test case 2
    start_words_tuple2 = tuple(start_words2)

    # Generate and print output for test case 1
    print("Test Case 1:")
    for chain_length in chain_lengths1:
        markov_chain1 = build_markov_chain(sample_text, chain_length)
        print_markov_chain(markov_chain1, chain_length)
        generated_sentence1 = generate_sentence(markov_chain1, start_word1, num_generated1)
        print("\nGenerated Sentence:")
        print(generated_sentence1)
        print("-" * 50)

    # Generate and print output for test case 2
    print("\nTest Case 2:")
    for chain_length in chain_lengths2:
        markov_chain2 = build_markov_chain(sample_text, chain_length)
        print_markov_chain(markov_chain2, chain_length)
        generated_sentence2 = generate_sentence(markov_chain2, start_words_tuple2, num_generated2)
        print("\nGenerated Sentence:")
        print(generated_sentence2)
        print("-" * 50)

    # Generate and print output for test case 3
    print("\nTest Case 3 (Empty Sample Text):")
    try:
        markov_chain_empty = build_markov_chain(empty_sample_text, 2)
        print_markov_chain(markov_chain_empty, 2)
        generated_sentence_empty = generate_sentence(markov_chain_empty, ['Alice'], 10)
        print("\nGenerated Sentence:")
        print(generated_sentence_empty)
        print("-" * 50)
    except ValueError as e:
        print(e)

if __name__ == "__main__":
    main()
# Out:
# Test Case 1:
# Markov Chain Dictionary (Chain Length: 2):
# ('Alice,', 'a') -> ['young']
# ('a', 'young') -> ['girl,']
# ('young', 'girl,') -> ['sits']
# ('girl,', 'sits') -> ['bored']
# ('sits', 'bored') -> ['by']
# ('bored', 'by') -> ['a']
# ('by', 'a') -> ['riverbank']
# ('a', 'riverbank') -> ['and']
# ('riverbank', 'and') -> ['spots']
# ('and', 'spots') -> ['a']
# ('spots', 'a') -> ['White']
# ('a', 'White') -> ['Rabbit']
# ('White', 'Rabbit') -> ['with', 'flees']
# ('Rabbit', 'with') -> ['a']
# ('with', 'a') -> ['pocket', 'table,']
# ('a', 'pocket') -> ['watch']
# ('pocket', 'watch') -> ['and']
# ('watch', 'and') -> ['waistcoat']
# ('and', 'waistcoat') -> ['lamenting']
# ('waistcoat', 'lamenting') -> ['that']
# ('lamenting', 'that') -> ['he']
# ('that', 'he') -> ['is']
# ('he', 'is') -> ['late.']
# ('is', 'late.') -> ['Surprised,']
# ('late.', 'Surprised,') -> ['Alice']
# ('Surprised,', 'Alice') -> ['follows']
# ('Alice', 'follows') -> ['him']
# ('follows', 'him') -> ['down']
# ('him', 'down') -> ['a']
# ('down', 'a') -> ['rabbit']
# ('a', 'rabbit') -> ['hole,']
# ('rabbit', 'hole,') -> ['which']
# ('hole,', 'which') -> ['sends']
# ('which', 'sends') -> ['her']
# ('sends', 'her') -> ['into']
# ('her', 'into') -> ['a']
# ('into', 'a') -> ['lengthy']
# ('a', 'lengthy') -> ['plummet']
# ('lengthy', 'plummet') -> ['but']
# ('plummet', 'but') -> ['to']
# ('but', 'to') -> ['a']
# ('to', 'a') -> ['safe', 'tiny', 'tremendous']
# ('a', 'safe') -> ['landing.']
# ('safe', 'landing.') -> ['Inside']
# ('landing.', 'Inside') -> ['a']
# ('Inside', 'a') -> ['room']
# ('a', 'room') -> ['with']
# ('room', 'with') -> ['a']
# ('a', 'table,') -> ['she']
# ('table,', 'she') -> ['finds']
# ('she', 'finds') -> ['a']
# ('finds', 'a') -> ['key']
# ('a', 'key') -> ['to']
# ('key', 'to') -> ['a']
# ('a', 'tiny') -> ['door,']
# ('tiny', 'door,') -> ['beyond']
# ('door,', 'beyond') -> ['which']
# ('beyond', 'which') -> ['is']
# ('which', 'is') -> ['a']
# ('is', 'a') -> ['garden.']
# ('a', 'garden.') -> ['While']
# ('garden.', 'While') -> ['pondering']
# ('While', 'pondering') -> ['how']
# ('pondering', 'how') -> ['to']
# ('how', 'to') -> ['fit']
# ('to', 'fit') -> ['through']
# ('fit', 'through') -> ['the']
# ('through', 'the') -> ['door,']
# ('the', 'door,') -> ['she']
# ('door,', 'she') -> ['discovers']
# ('she', 'discovers') -> ['a']
# ('discovers', 'a') -> ['bottle']
# ('a', 'bottle') -> ['labelled']
# ('bottle', 'labelled') -> ['"Drink']
# ('labelled', '"Drink') -> ['me".']
# ('"Drink', 'me".') -> ['Alice']
# ('me".', 'Alice') -> ['drinks']
# ('Alice', 'drinks') -> ['some']
# ('drinks', 'some') -> ['of']
# ('some', 'of') -> ['the']
# ('of', 'the') -> ["bottle's", 'race,']
# ('the', "bottle's") -> ['contents,']
# ("bottle's", 'contents,') -> ['and']
# ('contents,', 'and') -> ['to']
# ('and', 'to') -> ['her']
# ('to', 'her') -> ['astonishment,']
# ('her', 'astonishment,') -> ['she']
# ('astonishment,', 'she') -> ['shrinks']
# ('she', 'shrinks') -> ['small']
# ('shrinks', 'small') -> ['enough']
# ('small', 'enough') -> ['to']
# ('enough', 'to') -> ['enter']
# ('to', 'enter') -> ['the']
# ('enter', 'the') -> ['door.']
# ('the', 'door.') -> ['However,']
# ('door.', 'However,') -> ['she']
# ('However,', 'she') -> ['had']
# ('she', 'had') -> ['left']
# ('had', 'left') -> ['the']
# ('left', 'the') -> ['key']
# ('the', 'key') -> ['upon']
# ('key', 'upon') -> ['the']
# ('upon', 'the') -> ['table']
# ('the', 'table') -> ['and']
# ('table', 'and') -> ['cannot']
# ('and', 'cannot') -> ['reach']
# ('cannot', 'reach') -> ['it.']
# ('reach', 'it.') -> ['Alice']
# ('it.', 'Alice') -> ['then']
# ('Alice', 'then') -> ['discovers']
# ('then', 'discovers') -> ['and']
# ('discovers', 'and') -> ['eats']
# ('and', 'eats') -> ['a']
# ('eats', 'a') -> ['cake']
# ('a', 'cake') -> ['labelled']
# ('cake', 'labelled') -> ['"Eat']
# ('labelled', '"Eat') -> ['me",']
# ('"Eat', 'me",') -> ['which']
# ('me",', 'which') -> ['causes']
# ('which', 'causes') -> ['her', 'her']
# ('causes', 'her') -> ['to', 'to']
# ('her', 'to') -> ['grow', 'shrink']
# ('to', 'grow') -> ['to']
# ('grow', 'to') -> ['a']
# ('a', 'tremendous') -> ['size.']
# ('tremendous', 'size.') -> ['Unhappy,']
# ('size.', 'Unhappy,') -> ['Alice']
# ('Unhappy,', 'Alice') -> ['bursts']
# ('Alice', 'bursts') -> ['into']
# ('bursts', 'into') -> ['tears,']
# ('into', 'tears,') -> ['and']
# ('tears,', 'and') -> ['the']
# ('and', 'the') -> ['passing']
# ('the', 'passing') -> ['White']
# ('passing', 'White') -> ['Rabbit']
# ('Rabbit', 'flees') -> ['in']
# ('flees', 'in') -> ['a']
# ('in', 'a') -> ['panic,', 'pool', '"Caucus']
# ('a', 'panic,') -> ['dropping']
# ('panic,', 'dropping') -> ['a']
# ('dropping', 'a') -> ['fan']
# ('a', 'fan') -> ['and']
# ('fan', 'and') -> ['two']
# ('and', 'two') -> ['gloves.']
# ('two', 'gloves.') -> ['Alice']
# ('gloves.', 'Alice') -> ['uses']
# ('Alice', 'uses') -> ['the']
# ('uses', 'the') -> ['fan']
# ('the', 'fan') -> ['for']
# ('fan', 'for') -> ['herself,']
# ('for', 'herself,') -> ['which']
# ('herself,', 'which') -> ['causes']
# ('to', 'shrink') -> ['once']
# ('shrink', 'once') -> ['more']
# ('once', 'more') -> ['and']
# ('more', 'and') -> ['leaves']
# ('and', 'leaves') -> ['her']
# ('leaves', 'her') -> ['swimming']
# ('her', 'swimming') -> ['in']
# ('swimming', 'in') -> ['a']
# ('a', 'pool') -> ['of']
# ('pool', 'of') -> ['her']
# ('of', 'her') -> ['own']
# ('her', 'own') -> ['tears.']
# ('own', 'tears.') -> ['Within']
# ('tears.', 'Within') -> ['the']
# ('Within', 'the') -> ['pool,']
# ('the', 'pool,') -> ['Alice']
# ('pool,', 'Alice') -> ['meets']
# ('Alice', 'meets') -> ['various']
# ('meets', 'various') -> ['animals']
# ('various', 'animals') -> ['and']
# ('animals', 'and') -> ['birds,']
# ('and', 'birds,') -> ['who']
# ('birds,', 'who') -> ['convene']
# ('who', 'convene') -> ['on']
# ('convene', 'on') -> ['a']
# ('on', 'a') -> ['bank']
# ('a', 'bank') -> ['and']
# ('bank', 'and') -> ['engage']
# ('and', 'engage') -> ['in']
# ('engage', 'in') -> ['a']
# ('a', '"Caucus') -> ['Race"']
# ('"Caucus', 'Race"') -> ['to']
# ('Race"', 'to') -> ['dry']
# ('to', 'dry') -> ['themselves.']
# ('dry', 'themselves.') -> ['Following']
# ('themselves.', 'Following') -> ['the']
# ('Following', 'the') -> ['end']
# ('the', 'end') -> ['of']
# ('end', 'of') -> ['the']
# ('the', 'race,') -> ['Alice']
# ('race,', 'Alice') -> ['inadvertently']
# ('Alice', 'inadvertently') -> ['frightens']
# ('inadvertently', 'frightens') -> ['the']
# ('frightens', 'the') -> ['animals']
# ('the', 'animals') -> ['away']
# ('animals', 'away') -> ['by']
# ('away', 'by') -> ['discussing']
# ('by', 'discussing') -> ['her']
# ('discussing', 'her') -> ['cat.']
#
# Generated Sentence:
# Alice
# --------------------------------------------------
# Markov Chain Dictionary (Chain Length: 3):
# ('Alice,', 'a', 'young') -> ['girl,']
# ('a', 'young', 'girl,') -> ['sits']
# ('young', 'girl,', 'sits') -> ['bored']
# ('girl,', 'sits', 'bored') -> ['by']
# ('sits', 'bored', 'by') -> ['a']
# ('bored', 'by', 'a') -> ['riverbank']
# ('by', 'a', 'riverbank') -> ['and']
# ('a', 'riverbank', 'and') -> ['spots']
# ('riverbank', 'and', 'spots') -> ['a']
# ('and', 'spots', 'a') -> ['White']
# ('spots', 'a', 'White') -> ['Rabbit']
# ('a', 'White', 'Rabbit') -> ['with']
# ('White', 'Rabbit', 'with') -> ['a']
# ('Rabbit', 'with', 'a') -> ['pocket']
# ('with', 'a', 'pocket') -> ['watch']
# ('a', 'pocket', 'watch') -> ['and']
# ('pocket', 'watch', 'and') -> ['waistcoat']
# ('watch', 'and', 'waistcoat') -> ['lamenting']
# ('and', 'waistcoat', 'lamenting') -> ['that']
# ('waistcoat', 'lamenting', 'that') -> ['he']
# ('lamenting', 'that', 'he') -> ['is']
# ('that', 'he', 'is') -> ['late.']
# ('he', 'is', 'late.') -> ['Surprised,']
# ('is', 'late.', 'Surprised,') -> ['Alice']
# ('late.', 'Surprised,', 'Alice') -> ['follows']
# ('Surprised,', 'Alice', 'follows') -> ['him']
# ('Alice', 'follows', 'him') -> ['down']
# ('follows', 'him', 'down') -> ['a']
# ('him', 'down', 'a') -> ['rabbit']
# ('down', 'a', 'rabbit') -> ['hole,']
# ('a', 'rabbit', 'hole,') -> ['which']
# ('rabbit', 'hole,', 'which') -> ['sends']
# ('hole,', 'which', 'sends') -> ['her']
# ('which', 'sends', 'her') -> ['into']
# ('sends', 'her', 'into') -> ['a']
# ('her', 'into', 'a') -> ['lengthy']
# ('into', 'a', 'lengthy') -> ['plummet']
# ('a', 'lengthy', 'plummet') -> ['but']
# ('lengthy', 'plummet', 'but') -> ['to']
# ('plummet', 'but', 'to') -> ['a']
# ('but', 'to', 'a') -> ['safe']
# ('to', 'a', 'safe') -> ['landing.']
# ('a', 'safe', 'landing.') -> ['Inside']
# ('safe', 'landing.', 'Inside') -> ['a']
# ('landing.', 'Inside', 'a') -> ['room']
# ('Inside', 'a', 'room') -> ['with']
# ('a', 'room', 'with') -> ['a']
# ('room', 'with', 'a') -> ['table,']
# ('with', 'a', 'table,') -> ['she']
# ('a', 'table,', 'she') -> ['finds']
# ('table,', 'she', 'finds') -> ['a']
# ('she', 'finds', 'a') -> ['key']
# ('finds', 'a', 'key') -> ['to']
# ('a', 'key', 'to') -> ['a']
# ('key', 'to', 'a') -> ['tiny']
# ('to', 'a', 'tiny') -> ['door,']
# ('a', 'tiny', 'door,') -> ['beyond']
# ('tiny', 'door,', 'beyond') -> ['which']
# ('door,', 'beyond', 'which') -> ['is']
# ('beyond', 'which', 'is') -> ['a']
# ('which', 'is', 'a') -> ['garden.']
# ('is', 'a', 'garden.') -> ['While']
# ('a', 'garden.', 'While') -> ['pondering']
# ('garden.', 'While', 'pondering') -> ['how']
# ('While', 'pondering', 'how') -> ['to']
# ('pondering', 'how', 'to') -> ['fit']
# ('how', 'to', 'fit') -> ['through']
# ('to', 'fit', 'through') -> ['the']
# ('fit', 'through', 'the') -> ['door,']
# ('through', 'the', 'door,') -> ['she']
# ('the', 'door,', 'she') -> ['discovers']
# ('door,', 'she', 'discovers') -> ['a']
# ('she', 'discovers', 'a') -> ['bottle']
# ('discovers', 'a', 'bottle') -> ['labelled']
# ('a', 'bottle', 'labelled') -> ['"Drink']
# ('bottle', 'labelled', '"Drink') -> ['me".']
# ('labelled', '"Drink', 'me".') -> ['Alice']
# ('"Drink', 'me".', 'Alice') -> ['drinks']
# ('me".', 'Alice', 'drinks') -> ['some']
# ('Alice', 'drinks', 'some') -> ['of']
# ('drinks', 'some', 'of') -> ['the']
# ('some', 'of', 'the') -> ["bottle's"]
# ('of', 'the', "bottle's") -> ['contents,']
# ('the', "bottle's", 'contents,') -> ['and']
# ("bottle's", 'contents,', 'and') -> ['to']
# ('contents,', 'and', 'to') -> ['her']
# ('and', 'to', 'her') -> ['astonishment,']
# ('to', 'her', 'astonishment,') -> ['she']
# ('her', 'astonishment,', 'she') -> ['shrinks']
# ('astonishment,', 'she', 'shrinks') -> ['small']
# ('she', 'shrinks', 'small') -> ['enough']
# ('shrinks', 'small', 'enough') -> ['to']
# ('small', 'enough', 'to') -> ['enter']
# ('enough', 'to', 'enter') -> ['the']
# ('to', 'enter', 'the') -> ['door.']
# ('enter', 'the', 'door.') -> ['However,']
# ('the', 'door.', 'However,') -> ['she']
# ('door.', 'However,', 'she') -> ['had']
# ('However,', 'she', 'had') -> ['left']
# ('she', 'had', 'left') -> ['the']
# ('had', 'left', 'the') -> ['key']
# ('left', 'the', 'key') -> ['upon']
# ('the', 'key', 'upon') -> ['the']
# ('key', 'upon', 'the') -> ['table']
# ('upon', 'the', 'table') -> ['and']
# ('the', 'table', 'and') -> ['cannot']
# ('table', 'and', 'cannot') -> ['reach']
# ('and', 'cannot', 'reach') -> ['it.']
# ('cannot', 'reach', 'it.') -> ['Alice']
# ('reach', 'it.', 'Alice') -> ['then']
# ('it.', 'Alice', 'then') -> ['discovers']
# ('Alice', 'then', 'discovers') -> ['and']
# ('then', 'discovers', 'and') -> ['eats']
# ('discovers', 'and', 'eats') -> ['a']
# ('and', 'eats', 'a') -> ['cake']
# ('eats', 'a', 'cake') -> ['labelled']
# ('a', 'cake', 'labelled') -> ['"Eat']
# ('cake', 'labelled', '"Eat') -> ['me",']
# ('labelled', '"Eat', 'me",') -> ['which']
# ('"Eat', 'me",', 'which') -> ['causes']
# ('me",', 'which', 'causes') -> ['her']
# ('which', 'causes', 'her') -> ['to', 'to']
# ('causes', 'her', 'to') -> ['grow', 'shrink']
# ('her', 'to', 'grow') -> ['to']
# ('to', 'grow', 'to') -> ['a']
# ('grow', 'to', 'a') -> ['tremendous']
# ('to', 'a', 'tremendous') -> ['size.']
# ('a', 'tremendous', 'size.') -> ['Unhappy,']
# ('tremendous', 'size.', 'Unhappy,') -> ['Alice']
# ('size.', 'Unhappy,', 'Alice') -> ['bursts']
# ('Unhappy,', 'Alice', 'bursts') -> ['into']
# ('Alice', 'bursts', 'into') -> ['tears,']
# ('bursts', 'into', 'tears,') -> ['and']
# ('into', 'tears,', 'and') -> ['the']
# ('tears,', 'and', 'the') -> ['passing']
# ('and', 'the', 'passing') -> ['White']
# ('the', 'passing', 'White') -> ['Rabbit']
# ('passing', 'White', 'Rabbit') -> ['flees']
# ('White', 'Rabbit', 'flees') -> ['in']
# ('Rabbit', 'flees', 'in') -> ['a']
# ('flees', 'in', 'a') -> ['panic,']
# ('in', 'a', 'panic,') -> ['dropping']
# ('a', 'panic,', 'dropping') -> ['a']
# ('panic,', 'dropping', 'a') -> ['fan']
# ('dropping', 'a', 'fan') -> ['and']
# ('a', 'fan', 'and') -> ['two']
# ('fan', 'and', 'two') -> ['gloves.']
# ('and', 'two', 'gloves.') -> ['Alice']
# ('two', 'gloves.', 'Alice') -> ['uses']
# ('gloves.', 'Alice', 'uses') -> ['the']
# ('Alice', 'uses', 'the') -> ['fan']
# ('uses', 'the', 'fan') -> ['for']
# ('the', 'fan', 'for') -> ['herself,']
# ('fan', 'for', 'herself,') -> ['which']
# ('for', 'herself,', 'which') -> ['causes']
# ('herself,', 'which', 'causes') -> ['her']
# ('her', 'to', 'shrink') -> ['once']
# ('to', 'shrink', 'once') -> ['more']
# ('shrink', 'once', 'more') -> ['and']
# ('once', 'more', 'and') -> ['leaves']
# ('more', 'and', 'leaves') -> ['her']
# ('and', 'leaves', 'her') -> ['swimming']
# ('leaves', 'her', 'swimming') -> ['in']
# ('her', 'swimming', 'in') -> ['a']
# ('swimming', 'in', 'a') -> ['pool']
# ('in', 'a', 'pool') -> ['of']
# ('a', 'pool', 'of') -> ['her']
# ('pool', 'of', 'her') -> ['own']
# ('of', 'her', 'own') -> ['tears.']
# ('her', 'own', 'tears.') -> ['Within']
# ('own', 'tears.', 'Within') -> ['the']
# ('tears.', 'Within', 'the') -> ['pool,']
# ('Within', 'the', 'pool,') -> ['Alice']
# ('the', 'pool,', 'Alice') -> ['meets']
# ('pool,', 'Alice', 'meets') -> ['various']
# ('Alice', 'meets', 'various') -> ['animals']
# ('meets', 'various', 'animals') -> ['and']
# ('various', 'animals', 'and') -> ['birds,']
# ('animals', 'and', 'birds,') -> ['who']
# ('and', 'birds,', 'who') -> ['convene']
# ('birds,', 'who', 'convene') -> ['on']
# ('who', 'convene', 'on') -> ['a']
# ('convene', 'on', 'a') -> ['bank']
# ('on', 'a', 'bank') -> ['and']
# ('a', 'bank', 'and') -> ['engage']
# ('bank', 'and', 'engage') -> ['in']
# ('and', 'engage', 'in') -> ['a']
# ('engage', 'in', 'a') -> ['"Caucus']
# ('in', 'a', '"Caucus') -> ['Race"']
# ('a', '"Caucus', 'Race"') -> ['to']
# ('"Caucus', 'Race"', 'to') -> ['dry']
# ('Race"', 'to', 'dry') -> ['themselves.']
# ('to', 'dry', 'themselves.') -> ['Following']
# ('dry', 'themselves.', 'Following') -> ['the']
# ('themselves.', 'Following', 'the') -> ['end']
# ('Following', 'the', 'end') -> ['of']
# ('the', 'end', 'of') -> ['the']
# ('end', 'of', 'the') -> ['race,']
# ('of', 'the', 'race,') -> ['Alice']
# ('the', 'race,', 'Alice') -> ['inadvertently']
# ('race,', 'Alice', 'inadvertently') -> ['frightens']
# ('Alice', 'inadvertently', 'frightens') -> ['the']
# ('inadvertently', 'frightens', 'the') -> ['animals']
# ('frightens', 'the', 'animals') -> ['away']
# ('the', 'animals', 'away') -> ['by']
# ('animals', 'away', 'by') -> ['discussing']
# ('away', 'by', 'discussing') -> ['her']
# ('by', 'discussing', 'her') -> ['cat.']
#
# Generated Sentence:
# Alice
# --------------------------------------------------
# Markov Chain Dictionary (Chain Length: 4):
# ('Alice,', 'a', 'young', 'girl,') -> ['sits']
# ('a', 'young', 'girl,', 'sits') -> ['bored']
# ('young', 'girl,', 'sits', 'bored') -> ['by']
# ('girl,', 'sits', 'bored', 'by') -> ['a']
# ('sits', 'bored', 'by', 'a') -> ['riverbank']
# ('bored', 'by', 'a', 'riverbank') -> ['and']
# ('by', 'a', 'riverbank', 'and') -> ['spots']
# ('a', 'riverbank', 'and', 'spots') -> ['a']
# ('riverbank', 'and', 'spots', 'a') -> ['White']
# ('and', 'spots', 'a', 'White') -> ['Rabbit']
# ('spots', 'a', 'White', 'Rabbit') -> ['with']
# ('a', 'White', 'Rabbit', 'with') -> ['a']
# ('White', 'Rabbit', 'with', 'a') -> ['pocket']
# ('Rabbit', 'with', 'a', 'pocket') -> ['watch']
# ('with', 'a', 'pocket', 'watch') -> ['and']
# ('a', 'pocket', 'watch', 'and') -> ['waistcoat']
# ('pocket', 'watch', 'and', 'waistcoat') -> ['lamenting']
# ('watch', 'and', 'waistcoat', 'lamenting') -> ['that']
# ('and', 'waistcoat', 'lamenting', 'that') -> ['he']
# ('waistcoat', 'lamenting', 'that', 'he') -> ['is']
# ('lamenting', 'that', 'he', 'is') -> ['late.']
# ('that', 'he', 'is', 'late.') -> ['Surprised,']
# ('he', 'is', 'late.', 'Surprised,') -> ['Alice']
# ('is', 'late.', 'Surprised,', 'Alice') -> ['follows']
# ('late.', 'Surprised,', 'Alice', 'follows') -> ['him']
# ('Surprised,', 'Alice', 'follows', 'him') -> ['down']
# ('Alice', 'follows', 'him', 'down') -> ['a']
# ('follows', 'him', 'down', 'a') -> ['rabbit']
# ('him', 'down', 'a', 'rabbit') -> ['hole,']
# ('down', 'a', 'rabbit', 'hole,') -> ['which']
# ('a', 'rabbit', 'hole,', 'which') -> ['sends']
# ('rabbit', 'hole,', 'which', 'sends') -> ['her']
# ('hole,', 'which', 'sends', 'her') -> ['into']
# ('which', 'sends', 'her', 'into') -> ['a']
# ('sends', 'her', 'into', 'a') -> ['lengthy']
# ('her', 'into', 'a', 'lengthy') -> ['plummet']
# ('into', 'a', 'lengthy', 'plummet') -> ['but']
# ('a', 'lengthy', 'plummet', 'but') -> ['to']
# ('lengthy', 'plummet', 'but', 'to') -> ['a']
# ('plummet', 'but', 'to', 'a') -> ['safe']
# ('but', 'to', 'a', 'safe') -> ['landing.']
# ('to', 'a', 'safe', 'landing.') -> ['Inside']
# ('a', 'safe', 'landing.', 'Inside') -> ['a']
# ('safe', 'landing.', 'Inside', 'a') -> ['room']
# ('landing.', 'Inside', 'a', 'room') -> ['with']
# ('Inside', 'a', 'room', 'with') -> ['a']
# ('a', 'room', 'with', 'a') -> ['table,']
# ('room', 'with', 'a', 'table,') -> ['she']
# ('with', 'a', 'table,', 'she') -> ['finds']
# ('a', 'table,', 'she', 'finds') -> ['a']
# ('table,', 'she', 'finds', 'a') -> ['key']
# ('she', 'finds', 'a', 'key') -> ['to']
# ('finds', 'a', 'key', 'to') -> ['a']
# ('a', 'key', 'to', 'a') -> ['tiny']
# ('key', 'to', 'a', 'tiny') -> ['door,']
# ('to', 'a', 'tiny', 'door,') -> ['beyond']
# ('a', 'tiny', 'door,', 'beyond') -> ['which']
# ('tiny', 'door,', 'beyond', 'which') -> ['is']
# ('door,', 'beyond', 'which', 'is') -> ['a']
# ('beyond', 'which', 'is', 'a') -> ['garden.']
# ('which', 'is', 'a', 'garden.') -> ['While']
# ('is', 'a', 'garden.', 'While') -> ['pondering']
# ('a', 'garden.', 'While', 'pondering') -> ['how']
# ('garden.', 'While', 'pondering', 'how') -> ['to']
# ('While', 'pondering', 'how', 'to') -> ['fit']
# ('pondering', 'how', 'to', 'fit') -> ['through']
# ('how', 'to', 'fit', 'through') -> ['the']
# ('to', 'fit', 'through', 'the') -> ['door,']
# ('fit', 'through', 'the', 'door,') -> ['she']
# ('through', 'the', 'door,', 'she') -> ['discovers']
# ('the', 'door,', 'she', 'discovers') -> ['a']
# ('door,', 'she', 'discovers', 'a') -> ['bottle']
# ('she', 'discovers', 'a', 'bottle') -> ['labelled']
# ('discovers', 'a', 'bottle', 'labelled') -> ['"Drink']
# ('a', 'bottle', 'labelled', '"Drink') -> ['me".']
# ('bottle', 'labelled', '"Drink', 'me".') -> ['Alice']
# ('labelled', '"Drink', 'me".', 'Alice') -> ['drinks']
# ('"Drink', 'me".', 'Alice', 'drinks') -> ['some']
# ('me".', 'Alice', 'drinks', 'some') -> ['of']
# ('Alice', 'drinks', 'some', 'of') -> ['the']
# ('drinks', 'some', 'of', 'the') -> ["bottle's"]
# ('some', 'of', 'the', "bottle's") -> ['contents,']
# ('of', 'the', "bottle's", 'contents,') -> ['and']
# ('the', "bottle's", 'contents,', 'and') -> ['to']
# ("bottle's", 'contents,', 'and', 'to') -> ['her']
# ('contents,', 'and', 'to', 'her') -> ['astonishment,']
# ('and', 'to', 'her', 'astonishment,') -> ['she']
# ('to', 'her', 'astonishment,', 'she') -> ['shrinks']
# ('her', 'astonishment,', 'she', 'shrinks') -> ['small']
# ('astonishment,', 'she', 'shrinks', 'small') -> ['enough']
# ('she', 'shrinks', 'small', 'enough') -> ['to']
# ('shrinks', 'small', 'enough', 'to') -> ['enter']
# ('small', 'enough', 'to', 'enter') -> ['the']
# ('enough', 'to', 'enter', 'the') -> ['door.']
# ('to', 'enter', 'the', 'door.') -> ['However,']
# ('enter', 'the', 'door.', 'However,') -> ['she']
# ('the', 'door.', 'However,', 'she') -> ['had']
# ('door.', 'However,', 'she', 'had') -> ['left']
# ('However,', 'she', 'had', 'left') -> ['the']
# ('she', 'had', 'left', 'the') -> ['key']
# ('had', 'left', 'the', 'key') -> ['upon']
# ('left', 'the', 'key', 'upon') -> ['the']
# ('the', 'key', 'upon', 'the') -> ['table']
# ('key', 'upon', 'the', 'table') -> ['and']
# ('upon', 'the', 'table', 'and') -> ['cannot']
# ('the', 'table', 'and', 'cannot') -> ['reach']
# ('table', 'and', 'cannot', 'reach') -> ['it.']
# ('and', 'cannot', 'reach', 'it.') -> ['Alice']
# ('cannot', 'reach', 'it.', 'Alice') -> ['then']
# ('reach', 'it.', 'Alice', 'then') -> ['discovers']
# ('it.', 'Alice', 'then', 'discovers') -> ['and']
# ('Alice', 'then', 'discovers', 'and') -> ['eats']
# ('then', 'discovers', 'and', 'eats') -> ['a']
# ('discovers', 'and', 'eats', 'a') -> ['cake']
# ('and', 'eats', 'a', 'cake') -> ['labelled']
# ('eats', 'a', 'cake', 'labelled') -> ['"Eat']
# ('a', 'cake', 'labelled', '"Eat') -> ['me",']
# ('cake', 'labelled', '"Eat', 'me",') -> ['which']
# ('labelled', '"Eat', 'me",', 'which') -> ['causes']
# ('"Eat', 'me",', 'which', 'causes') -> ['her']
# ('me",', 'which', 'causes', 'her') -> ['to']
# ('which', 'causes', 'her', 'to') -> ['grow', 'shrink']
# ('causes', 'her', 'to', 'grow') -> ['to']
# ('her', 'to', 'grow', 'to') -> ['a']
# ('to', 'grow', 'to', 'a') -> ['tremendous']
# ('grow', 'to', 'a', 'tremendous') -> ['size.']
# ('to', 'a', 'tremendous', 'size.') -> ['Unhappy,']
# ('a', 'tremendous', 'size.', 'Unhappy,') -> ['Alice']
# ('tremendous', 'size.', 'Unhappy,', 'Alice') -> ['bursts']
# ('size.', 'Unhappy,', 'Alice', 'bursts') -> ['into']
# ('Unhappy,', 'Alice', 'bursts', 'into') -> ['tears,']
# ('Alice', 'bursts', 'into', 'tears,') -> ['and']
# ('bursts', 'into', 'tears,', 'and') -> ['the']
# ('into', 'tears,', 'and', 'the') -> ['passing']
# ('tears,', 'and', 'the', 'passing') -> ['White']
# ('and', 'the', 'passing', 'White') -> ['Rabbit']
# ('the', 'passing', 'White', 'Rabbit') -> ['flees']
# ('passing', 'White', 'Rabbit', 'flees') -> ['in']
# ('White', 'Rabbit', 'flees', 'in') -> ['a']
# ('Rabbit', 'flees', 'in', 'a') -> ['panic,']
# ('flees', 'in', 'a', 'panic,') -> ['dropping']
# ('in', 'a', 'panic,', 'dropping') -> ['a']
# ('a', 'panic,', 'dropping', 'a') -> ['fan']
# ('panic,', 'dropping', 'a', 'fan') -> ['and']
# ('dropping', 'a', 'fan', 'and') -> ['two']
# ('a', 'fan', 'and', 'two') -> ['gloves.']
# ('fan', 'and', 'two', 'gloves.') -> ['Alice']
# ('and', 'two', 'gloves.', 'Alice') -> ['uses']
# ('two', 'gloves.', 'Alice', 'uses') -> ['the']
# ('gloves.', 'Alice', 'uses', 'the') -> ['fan']
# ('Alice', 'uses', 'the', 'fan') -> ['for']
# ('uses', 'the', 'fan', 'for') -> ['herself,']
# ('the', 'fan', 'for', 'herself,') -> ['which']
# ('fan', 'for', 'herself,', 'which') -> ['causes']
# ('for', 'herself,', 'which', 'causes') -> ['her']
# ('herself,', 'which', 'causes', 'her') -> ['to']
# ('causes', 'her', 'to', 'shrink') -> ['once']
# ('her', 'to', 'shrink', 'once') -> ['more']
# ('to', 'shrink', 'once', 'more') -> ['and']
# ('shrink', 'once', 'more', 'and') -> ['leaves']
# ('once', 'more', 'and', 'leaves') -> ['her']
# ('more', 'and', 'leaves', 'her') -> ['swimming']
# ('and', 'leaves', 'her', 'swimming') -> ['in']
# ('leaves', 'her', 'swimming', 'in') -> ['a']
# ('her', 'swimming', 'in', 'a') -> ['pool']
# ('swimming', 'in', 'a', 'pool') -> ['of']
# ('in', 'a', 'pool', 'of') -> ['her']
# ('a', 'pool', 'of', 'her') -> ['own']
# ('pool', 'of', 'her', 'own') -> ['tears.']
# ('of', 'her', 'own', 'tears.') -> ['Within']
# ('her', 'own', 'tears.', 'Within') -> ['the']
# ('own', 'tears.', 'Within', 'the') -> ['pool,']
# ('tears.', 'Within', 'the', 'pool,') -> ['Alice']
# ('Within', 'the', 'pool,', 'Alice') -> ['meets']
# ('the', 'pool,', 'Alice', 'meets') -> ['various']
# ('pool,', 'Alice', 'meets', 'various') -> ['animals']
# ('Alice', 'meets', 'various', 'animals') -> ['and']
# ('meets', 'various', 'animals', 'and') -> ['birds,']
# ('various', 'animals', 'and', 'birds,') -> ['who']
# ('animals', 'and', 'birds,', 'who') -> ['convene']
# ('and', 'birds,', 'who', 'convene') -> ['on']
# ('birds,', 'who', 'convene', 'on') -> ['a']
# ('who', 'convene', 'on', 'a') -> ['bank']
# ('convene', 'on', 'a', 'bank') -> ['and']
# ('on', 'a', 'bank', 'and') -> ['engage']
# ('a', 'bank', 'and', 'engage') -> ['in']
# ('bank', 'and', 'engage', 'in') -> ['a']
# ('and', 'engage', 'in', 'a') -> ['"Caucus']
# ('engage', 'in', 'a', '"Caucus') -> ['Race"']
# ('in', 'a', '"Caucus', 'Race"') -> ['to']
# ('a', '"Caucus', 'Race"', 'to') -> ['dry']
# ('"Caucus', 'Race"', 'to', 'dry') -> ['themselves.']
# ('Race"', 'to', 'dry', 'themselves.') -> ['Following']
# ('to', 'dry', 'themselves.', 'Following') -> ['the']
# ('dry', 'themselves.', 'Following', 'the') -> ['end']
# ('themselves.', 'Following', 'the', 'end') -> ['of']
# ('Following', 'the', 'end', 'of') -> ['the']
# ('the', 'end', 'of', 'the') -> ['race,']
# ('end', 'of', 'the', 'race,') -> ['Alice']
# ('of', 'the', 'race,', 'Alice') -> ['inadvertently']
# ('the', 'race,', 'Alice', 'inadvertently') -> ['frightens']
# ('race,', 'Alice', 'inadvertently', 'frightens') -> ['the']
# ('Alice', 'inadvertently', 'frightens', 'the') -> ['animals']
# ('inadvertently', 'frightens', 'the', 'animals') -> ['away']
# ('frightens', 'the', 'animals', 'away') -> ['by']
# ('the', 'animals', 'away', 'by') -> ['discussing']
# ('animals', 'away', 'by', 'discussing') -> ['her']
# ('away', 'by', 'discussing', 'her') -> ['cat.']
#
# Generated Sentence:
# Alice
# --------------------------------------------------
#
# Test Case 2:
# Markov Chain Dictionary (Chain Length: 2):
# ('Alice,', 'a') -> ['young']
# ('a', 'young') -> ['girl,']
# ('young', 'girl,') -> ['sits']
# ('girl,', 'sits') -> ['bored']
# ('sits', 'bored') -> ['by']
# ('bored', 'by') -> ['a']
# ('by', 'a') -> ['riverbank']
# ('a', 'riverbank') -> ['and']
# ('riverbank', 'and') -> ['spots']
# ('and', 'spots') -> ['a']
# ('spots', 'a') -> ['White']
# ('a', 'White') -> ['Rabbit']
# ('White', 'Rabbit') -> ['with', 'flees']
# ('Rabbit', 'with') -> ['a']
# ('with', 'a') -> ['pocket', 'table,']
# ('a', 'pocket') -> ['watch']
# ('pocket', 'watch') -> ['and']
# ('watch', 'and') -> ['waistcoat']
# ('and', 'waistcoat') -> ['lamenting']
# ('waistcoat', 'lamenting') -> ['that']
# ('lamenting', 'that') -> ['he']
# ('that', 'he') -> ['is']
# ('he', 'is') -> ['late.']
# ('is', 'late.') -> ['Surprised,']
# ('late.', 'Surprised,') -> ['Alice']
# ('Surprised,', 'Alice') -> ['follows']
# ('Alice', 'follows') -> ['him']
# ('follows', 'him') -> ['down']
# ('him', 'down') -> ['a']
# ('down', 'a') -> ['rabbit']
# ('a', 'rabbit') -> ['hole,']
# ('rabbit', 'hole,') -> ['which']
# ('hole,', 'which') -> ['sends']
# ('which', 'sends') -> ['her']
# ('sends', 'her') -> ['into']
# ('her', 'into') -> ['a']
# ('into', 'a') -> ['lengthy']
# ('a', 'lengthy') -> ['plummet']
# ('lengthy', 'plummet') -> ['but']
# ('plummet', 'but') -> ['to']
# ('but', 'to') -> ['a']
# ('to', 'a') -> ['safe', 'tiny', 'tremendous']
# ('a', 'safe') -> ['landing.']
# ('safe', 'landing.') -> ['Inside']
# ('landing.', 'Inside') -> ['a']
# ('Inside', 'a') -> ['room']
# ('a', 'room') -> ['with']
# ('room', 'with') -> ['a']
# ('a', 'table,') -> ['she']
# ('table,', 'she') -> ['finds']
# ('she', 'finds') -> ['a']
# ('finds', 'a') -> ['key']
# ('a', 'key') -> ['to']
# ('key', 'to') -> ['a']
# ('a', 'tiny') -> ['door,']
# ('tiny', 'door,') -> ['beyond']
# ('door,', 'beyond') -> ['which']
# ('beyond', 'which') -> ['is']
# ('which', 'is') -> ['a']
# ('is', 'a') -> ['garden.']
# ('a', 'garden.') -> ['While']
# ('garden.', 'While') -> ['pondering']
# ('While', 'pondering') -> ['how']
# ('pondering', 'how') -> ['to']
# ('how', 'to') -> ['fit']
# ('to', 'fit') -> ['through']
# ('fit', 'through') -> ['the']
# ('through', 'the') -> ['door,']
# ('the', 'door,') -> ['she']
# ('door,', 'she') -> ['discovers']
# ('she', 'discovers') -> ['a']
# ('discovers', 'a') -> ['bottle']
# ('a', 'bottle') -> ['labelled']
# ('bottle', 'labelled') -> ['"Drink']
# ('labelled', '"Drink') -> ['me".']
# ('"Drink', 'me".') -> ['Alice']
# ('me".', 'Alice') -> ['drinks']
# ('Alice', 'drinks') -> ['some']
# ('drinks', 'some') -> ['of']
# ('some', 'of') -> ['the']
# ('of', 'the') -> ["bottle's", 'race,']
# ('the', "bottle's") -> ['contents,']
# ("bottle's", 'contents,') -> ['and']
# ('contents,', 'and') -> ['to']
# ('and', 'to') -> ['her']
# ('to', 'her') -> ['astonishment,']
# ('her', 'astonishment,') -> ['she']
# ('astonishment,', 'she') -> ['shrinks']
# ('she', 'shrinks') -> ['small']
# ('shrinks', 'small') -> ['enough']
# ('small', 'enough') -> ['to']
# ('enough', 'to') -> ['enter']
# ('to', 'enter') -> ['the']
# ('enter', 'the') -> ['door.']
# ('the', 'door.') -> ['However,']
# ('door.', 'However,') -> ['she']
# ('However,', 'she') -> ['had']
# ('she', 'had') -> ['left']
# ('had', 'left') -> ['the']
# ('left', 'the') -> ['key']
# ('the', 'key') -> ['upon']
# ('key', 'upon') -> ['the']
# ('upon', 'the') -> ['table']
# ('the', 'table') -> ['and']
# ('table', 'and') -> ['cannot']
# ('and', 'cannot') -> ['reach']
# ('cannot', 'reach') -> ['it.']
# ('reach', 'it.') -> ['Alice']
# ('it.', 'Alice') -> ['then']
# ('Alice', 'then') -> ['discovers']
# ('then', 'discovers') -> ['and']
# ('discovers', 'and') -> ['eats']
# ('and', 'eats') -> ['a']
# ('eats', 'a') -> ['cake']
# ('a', 'cake') -> ['labelled']
# ('cake', 'labelled') -> ['"Eat']
# ('labelled', '"Eat') -> ['me",']
# ('"Eat', 'me",') -> ['which']
# ('me",', 'which') -> ['causes']
# ('which', 'causes') -> ['her', 'her']
# ('causes', 'her') -> ['to', 'to']
# ('her', 'to') -> ['grow', 'shrink']
# ('to', 'grow') -> ['to']
# ('grow', 'to') -> ['a']
# ('a', 'tremendous') -> ['size.']
# ('tremendous', 'size.') -> ['Unhappy,']
# ('size.', 'Unhappy,') -> ['Alice']
# ('Unhappy,', 'Alice') -> ['bursts']
# ('Alice', 'bursts') -> ['into']
# ('bursts', 'into') -> ['tears,']
# ('into', 'tears,') -> ['and']
# ('tears,', 'and') -> ['the']
# ('and', 'the') -> ['passing']
# ('the', 'passing') -> ['White']
# ('passing', 'White') -> ['Rabbit']
# ('Rabbit', 'flees') -> ['in']
# ('flees', 'in') -> ['a']
# ('in', 'a') -> ['panic,', 'pool', '"Caucus']
# ('a', 'panic,') -> ['dropping']
# ('panic,', 'dropping') -> ['a']
# ('dropping', 'a') -> ['fan']
# ('a', 'fan') -> ['and']
# ('fan', 'and') -> ['two']
# ('and', 'two') -> ['gloves.']
# ('two', 'gloves.') -> ['Alice']
# ('gloves.', 'Alice') -> ['uses']
# ('Alice', 'uses') -> ['the']
# ('uses', 'the') -> ['fan']
# ('the', 'fan') -> ['for']
# ('fan', 'for') -> ['herself,']
# ('for', 'herself,') -> ['which']
# ('herself,', 'which') -> ['causes']
# ('to', 'shrink') -> ['once']
# ('shrink', 'once') -> ['more']
# ('once', 'more') -> ['and']
# ('more', 'and') -> ['leaves']
# ('and', 'leaves') -> ['her']
# ('leaves', 'her') -> ['swimming']
# ('her', 'swimming') -> ['in']
# ('swimming', 'in') -> ['a']
# ('a', 'pool') -> ['of']
# ('pool', 'of') -> ['her']
# ('of', 'her') -> ['own']
# ('her', 'own') -> ['tears.']
# ('own', 'tears.') -> ['Within']
# ('tears.', 'Within') -> ['the']
# ('Within', 'the') -> ['pool,']
# ('the', 'pool,') -> ['Alice']
# ('pool,', 'Alice') -> ['meets']
# ('Alice', 'meets') -> ['various']
# ('meets', 'various') -> ['animals']
# ('various', 'animals') -> ['and']
# ('animals', 'and') -> ['birds,']
# ('and', 'birds,') -> ['who']
# ('birds,', 'who') -> ['convene']
# ('who', 'convene') -> ['on']
# ('convene', 'on') -> ['a']
# ('on', 'a') -> ['bank']
# ('a', 'bank') -> ['and']
# ('bank', 'and') -> ['engage']
# ('and', 'engage') -> ['in']
# ('engage', 'in') -> ['a']
# ('a', '"Caucus') -> ['Race"']
# ('"Caucus', 'Race"') -> ['to']
# ('Race"', 'to') -> ['dry']
# ('to', 'dry') -> ['themselves.']
# ('dry', 'themselves.') -> ['Following']
# ('themselves.', 'Following') -> ['the']
# ('Following', 'the') -> ['end']
# ('the', 'end') -> ['of']
# ('end', 'of') -> ['the']
# ('the', 'race,') -> ['Alice']
# ('race,', 'Alice') -> ['inadvertently']
# ('Alice', 'inadvertently') -> ['frightens']
# ('inadvertently', 'frightens') -> ['the']
# ('frightens', 'the') -> ['animals']
# ('the', 'animals') -> ['away']
# ('animals', 'away') -> ['by']
# ('away', 'by') -> ['discussing']
# ('by', 'discussing') -> ['her']
# ('discussing', 'her') -> ['cat.']
#
# Generated Sentence:
# White Rabbit flees in a pool of her own tears. Within the pool, Alice meets various animals and birds, who
# --------------------------------------------------
# Markov Chain Dictionary (Chain Length: 3):
# ('Alice,', 'a', 'young') -> ['girl,']
# ('a', 'young', 'girl,') -> ['sits']
# ('young', 'girl,', 'sits') -> ['bored']
# ('girl,', 'sits', 'bored') -> ['by']
# ('sits', 'bored', 'by') -> ['a']
# ('bored', 'by', 'a') -> ['riverbank']
# ('by', 'a', 'riverbank') -> ['and']
# ('a', 'riverbank', 'and') -> ['spots']
# ('riverbank', 'and', 'spots') -> ['a']
# ('and', 'spots', 'a') -> ['White']
# ('spots', 'a', 'White') -> ['Rabbit']
# ('a', 'White', 'Rabbit') -> ['with']
# ('White', 'Rabbit', 'with') -> ['a']
# ('Rabbit', 'with', 'a') -> ['pocket']
# ('with', 'a', 'pocket') -> ['watch']
# ('a', 'pocket', 'watch') -> ['and']
# ('pocket', 'watch', 'and') -> ['waistcoat']
# ('watch', 'and', 'waistcoat') -> ['lamenting']
# ('and', 'waistcoat', 'lamenting') -> ['that']
# ('waistcoat', 'lamenting', 'that') -> ['he']
# ('lamenting', 'that', 'he') -> ['is']
# ('that', 'he', 'is') -> ['late.']
# ('he', 'is', 'late.') -> ['Surprised,']
# ('is', 'late.', 'Surprised,') -> ['Alice']
# ('late.', 'Surprised,', 'Alice') -> ['follows']
# ('Surprised,', 'Alice', 'follows') -> ['him']
# ('Alice', 'follows', 'him') -> ['down']
# ('follows', 'him', 'down') -> ['a']
# ('him', 'down', 'a') -> ['rabbit']
# ('down', 'a', 'rabbit') -> ['hole,']
# ('a', 'rabbit', 'hole,') -> ['which']
# ('rabbit', 'hole,', 'which') -> ['sends']
# ('hole,', 'which', 'sends') -> ['her']
# ('which', 'sends', 'her') -> ['into']
# ('sends', 'her', 'into') -> ['a']
# ('her', 'into', 'a') -> ['lengthy']
# ('into', 'a', 'lengthy') -> ['plummet']
# ('a', 'lengthy', 'plummet') -> ['but']
# ('lengthy', 'plummet', 'but') -> ['to']
# ('plummet', 'but', 'to') -> ['a']
# ('but', 'to', 'a') -> ['safe']
# ('to', 'a', 'safe') -> ['landing.']
# ('a', 'safe', 'landing.') -> ['Inside']
# ('safe', 'landing.', 'Inside') -> ['a']
# ('landing.', 'Inside', 'a') -> ['room']
# ('Inside', 'a', 'room') -> ['with']
# ('a', 'room', 'with') -> ['a']
# ('room', 'with', 'a') -> ['table,']
# ('with', 'a', 'table,') -> ['she']
# ('a', 'table,', 'she') -> ['finds']
# ('table,', 'she', 'finds') -> ['a']
# ('she', 'finds', 'a') -> ['key']
# ('finds', 'a', 'key') -> ['to']
# ('a', 'key', 'to') -> ['a']
# ('key', 'to', 'a') -> ['tiny']
# ('to', 'a', 'tiny') -> ['door,']
# ('a', 'tiny', 'door,') -> ['beyond']
# ('tiny', 'door,', 'beyond') -> ['which']
# ('door,', 'beyond', 'which') -> ['is']
# ('beyond', 'which', 'is') -> ['a']
# ('which', 'is', 'a') -> ['garden.']
# ('is', 'a', 'garden.') -> ['While']
# ('a', 'garden.', 'While') -> ['pondering']
# ('garden.', 'While', 'pondering') -> ['how']
# ('While', 'pondering', 'how') -> ['to']
# ('pondering', 'how', 'to') -> ['fit']
# ('how', 'to', 'fit') -> ['through']
# ('to', 'fit', 'through') -> ['the']
# ('fit', 'through', 'the') -> ['door,']
# ('through', 'the', 'door,') -> ['she']
# ('the', 'door,', 'she') -> ['discovers']
# ('door,', 'she', 'discovers') -> ['a']
# ('she', 'discovers', 'a') -> ['bottle']
# ('discovers', 'a', 'bottle') -> ['labelled']
# ('a', 'bottle', 'labelled') -> ['"Drink']
# ('bottle', 'labelled', '"Drink') -> ['me".']
# ('labelled', '"Drink', 'me".') -> ['Alice']
# ('"Drink', 'me".', 'Alice') -> ['drinks']
# ('me".', 'Alice', 'drinks') -> ['some']
# ('Alice', 'drinks', 'some') -> ['of']
# ('drinks', 'some', 'of') -> ['the']
# ('some', 'of', 'the') -> ["bottle's"]
# ('of', 'the', "bottle's") -> ['contents,']
# ('the', "bottle's", 'contents,') -> ['and']
# ("bottle's", 'contents,', 'and') -> ['to']
# ('contents,', 'and', 'to') -> ['her']
# ('and', 'to', 'her') -> ['astonishment,']
# ('to', 'her', 'astonishment,') -> ['she']
# ('her', 'astonishment,', 'she') -> ['shrinks']
# ('astonishment,', 'she', 'shrinks') -> ['small']
# ('she', 'shrinks', 'small') -> ['enough']
# ('shrinks', 'small', 'enough') -> ['to']
# ('small', 'enough', 'to') -> ['enter']
# ('enough', 'to', 'enter') -> ['the']
# ('to', 'enter', 'the') -> ['door.']
# ('enter', 'the', 'door.') -> ['However,']
# ('the', 'door.', 'However,') -> ['she']
# ('door.', 'However,', 'she') -> ['had']
# ('However,', 'she', 'had') -> ['left']
# ('she', 'had', 'left') -> ['the']
# ('had', 'left', 'the') -> ['key']
# ('left', 'the', 'key') -> ['upon']
# ('the', 'key', 'upon') -> ['the']
# ('key', 'upon', 'the') -> ['table']
# ('upon', 'the', 'table') -> ['and']
# ('the', 'table', 'and') -> ['cannot']
# ('table', 'and', 'cannot') -> ['reach']
# ('and', 'cannot', 'reach') -> ['it.']
# ('cannot', 'reach', 'it.') -> ['Alice']
# ('reach', 'it.', 'Alice') -> ['then']
# ('it.', 'Alice', 'then') -> ['discovers']
# ('Alice', 'then', 'discovers') -> ['and']
# ('then', 'discovers', 'and') -> ['eats']
# ('discovers', 'and', 'eats') -> ['a']
# ('and', 'eats', 'a') -> ['cake']
# ('eats', 'a', 'cake') -> ['labelled']
# ('a', 'cake', 'labelled') -> ['"Eat']
# ('cake', 'labelled', '"Eat') -> ['me",']
# ('labelled', '"Eat', 'me",') -> ['which']
# ('"Eat', 'me",', 'which') -> ['causes']
# ('me",', 'which', 'causes') -> ['her']
# ('which', 'causes', 'her') -> ['to', 'to']
# ('causes', 'her', 'to') -> ['grow', 'shrink']
# ('her', 'to', 'grow') -> ['to']
# ('to', 'grow', 'to') -> ['a']
# ('grow', 'to', 'a') -> ['tremendous']
# ('to', 'a', 'tremendous') -> ['size.']
# ('a', 'tremendous', 'size.') -> ['Unhappy,']
# ('tremendous', 'size.', 'Unhappy,') -> ['Alice']
# ('size.', 'Unhappy,', 'Alice') -> ['bursts']
# ('Unhappy,', 'Alice', 'bursts') -> ['into']
# ('Alice', 'bursts', 'into') -> ['tears,']
# ('bursts', 'into', 'tears,') -> ['and']
# ('into', 'tears,', 'and') -> ['the']
# ('tears,', 'and', 'the') -> ['passing']
# ('and', 'the', 'passing') -> ['White']
# ('the', 'passing', 'White') -> ['Rabbit']
# ('passing', 'White', 'Rabbit') -> ['flees']
# ('White', 'Rabbit', 'flees') -> ['in']
# ('Rabbit', 'flees', 'in') -> ['a']
# ('flees', 'in', 'a') -> ['panic,']
# ('in', 'a', 'panic,') -> ['dropping']
# ('a', 'panic,', 'dropping') -> ['a']
# ('panic,', 'dropping', 'a') -> ['fan']
# ('dropping', 'a', 'fan') -> ['and']
# ('a', 'fan', 'and') -> ['two']
# ('fan', 'and', 'two') -> ['gloves.']
# ('and', 'two', 'gloves.') -> ['Alice']
# ('two', 'gloves.', 'Alice') -> ['uses']
# ('gloves.', 'Alice', 'uses') -> ['the']
# ('Alice', 'uses', 'the') -> ['fan']
# ('uses', 'the', 'fan') -> ['for']
# ('the', 'fan', 'for') -> ['herself,']
# ('fan', 'for', 'herself,') -> ['which']
# ('for', 'herself,', 'which') -> ['causes']
# ('herself,', 'which', 'causes') -> ['her']
# ('her', 'to', 'shrink') -> ['once']
# ('to', 'shrink', 'once') -> ['more']
# ('shrink', 'once', 'more') -> ['and']
# ('once', 'more', 'and') -> ['leaves']
# ('more', 'and', 'leaves') -> ['her']
# ('and', 'leaves', 'her') -> ['swimming']
# ('leaves', 'her', 'swimming') -> ['in']
# ('her', 'swimming', 'in') -> ['a']
# ('swimming', 'in', 'a') -> ['pool']
# ('in', 'a', 'pool') -> ['of']
# ('a', 'pool', 'of') -> ['her']
# ('pool', 'of', 'her') -> ['own']
# ('of', 'her', 'own') -> ['tears.']
# ('her', 'own', 'tears.') -> ['Within']
# ('own', 'tears.', 'Within') -> ['the']
# ('tears.', 'Within', 'the') -> ['pool,']
# ('Within', 'the', 'pool,') -> ['Alice']
# ('the', 'pool,', 'Alice') -> ['meets']
# ('pool,', 'Alice', 'meets') -> ['various']
# ('Alice', 'meets', 'various') -> ['animals']
# ('meets', 'various', 'animals') -> ['and']
# ('various', 'animals', 'and') -> ['birds,']
# ('animals', 'and', 'birds,') -> ['who']
# ('and', 'birds,', 'who') -> ['convene']
# ('birds,', 'who', 'convene') -> ['on']
# ('who', 'convene', 'on') -> ['a']
# ('convene', 'on', 'a') -> ['bank']
# ('on', 'a', 'bank') -> ['and']
# ('a', 'bank', 'and') -> ['engage']
# ('bank', 'and', 'engage') -> ['in']
# ('and', 'engage', 'in') -> ['a']
# ('engage', 'in', 'a') -> ['"Caucus']
# ('in', 'a', '"Caucus') -> ['Race"']
# ('a', '"Caucus', 'Race"') -> ['to']
# ('"Caucus', 'Race"', 'to') -> ['dry']
# ('Race"', 'to', 'dry') -> ['themselves.']
# ('to', 'dry', 'themselves.') -> ['Following']
# ('dry', 'themselves.', 'Following') -> ['the']
# ('themselves.', 'Following', 'the') -> ['end']
# ('Following', 'the', 'end') -> ['of']
# ('the', 'end', 'of') -> ['the']
# ('end', 'of', 'the') -> ['race,']
# ('of', 'the', 'race,') -> ['Alice']
# ('the', 'race,', 'Alice') -> ['inadvertently']
# ('race,', 'Alice', 'inadvertently') -> ['frightens']
# ('Alice', 'inadvertently', 'frightens') -> ['the']
# ('inadvertently', 'frightens', 'the') -> ['animals']
# ('frightens', 'the', 'animals') -> ['away']
# ('the', 'animals', 'away') -> ['by']
# ('animals', 'away', 'by') -> ['discussing']
# ('away', 'by', 'discussing') -> ['her']
# ('by', 'discussing', 'her') -> ['cat.']
#
# Generated Sentence:
# White Rabbit
# --------------------------------------------------
# Markov Chain Dictionary (Chain Length: 4):
# ('Alice,', 'a', 'young', 'girl,') -> ['sits']
# ('a', 'young', 'girl,', 'sits') -> ['bored']
# ('young', 'girl,', 'sits', 'bored') -> ['by']
# ('girl,', 'sits', 'bored', 'by') -> ['a']
# ('sits', 'bored', 'by', 'a') -> ['riverbank']
# ('bored', 'by', 'a', 'riverbank') -> ['and']
# ('by', 'a', 'riverbank', 'and') -> ['spots']
# ('a', 'riverbank', 'and', 'spots') -> ['a']
# ('riverbank', 'and', 'spots', 'a') -> ['White']
# ('and', 'spots', 'a', 'White') -> ['Rabbit']
# ('spots', 'a', 'White', 'Rabbit') -> ['with']
# ('a', 'White', 'Rabbit', 'with') -> ['a']
# ('White', 'Rabbit', 'with', 'a') -> ['pocket']
# ('Rabbit', 'with', 'a', 'pocket') -> ['watch']
# ('with', 'a', 'pocket', 'watch') -> ['and']
# ('a', 'pocket', 'watch', 'and') -> ['waistcoat']
# ('pocket', 'watch', 'and', 'waistcoat') -> ['lamenting']
# ('watch', 'and', 'waistcoat', 'lamenting') -> ['that']
# ('and', 'waistcoat', 'lamenting', 'that') -> ['he']
# ('waistcoat', 'lamenting', 'that', 'he') -> ['is']
# ('lamenting', 'that', 'he', 'is') -> ['late.']
# ('that', 'he', 'is', 'late.') -> ['Surprised,']
# ('he', 'is', 'late.', 'Surprised,') -> ['Alice']
# ('is', 'late.', 'Surprised,', 'Alice') -> ['follows']
# ('late.', 'Surprised,', 'Alice', 'follows') -> ['him']
# ('Surprised,', 'Alice', 'follows', 'him') -> ['down']
# ('Alice', 'follows', 'him', 'down') -> ['a']
# ('follows', 'him', 'down', 'a') -> ['rabbit']
# ('him', 'down', 'a', 'rabbit') -> ['hole,']
# ('down', 'a', 'rabbit', 'hole,') -> ['which']
# ('a', 'rabbit', 'hole,', 'which') -> ['sends']
# ('rabbit', 'hole,', 'which', 'sends') -> ['her']
# ('hole,', 'which', 'sends', 'her') -> ['into']
# ('which', 'sends', 'her', 'into') -> ['a']
# ('sends', 'her', 'into', 'a') -> ['lengthy']
# ('her', 'into', 'a', 'lengthy') -> ['plummet']
# ('into', 'a', 'lengthy', 'plummet') -> ['but']
# ('a', 'lengthy', 'plummet', 'but') -> ['to']
# ('lengthy', 'plummet', 'but', 'to') -> ['a']
# ('plummet', 'but', 'to', 'a') -> ['safe']
# ('but', 'to', 'a', 'safe') -> ['landing.']
# ('to', 'a', 'safe', 'landing.') -> ['Inside']
# ('a', 'safe', 'landing.', 'Inside') -> ['a']
# ('safe', 'landing.', 'Inside', 'a') -> ['room']
# ('landing.', 'Inside', 'a', 'room') -> ['with']
# ('Inside', 'a', 'room', 'with') -> ['a']
# ('a', 'room', 'with', 'a') -> ['table,']
# ('room', 'with', 'a', 'table,') -> ['she']
# ('with', 'a', 'table,', 'she') -> ['finds']
# ('a', 'table,', 'she', 'finds') -> ['a']
# ('table,', 'she', 'finds', 'a') -> ['key']
# ('she', 'finds', 'a', 'key') -> ['to']
# ('finds', 'a', 'key', 'to') -> ['a']
# ('a', 'key', 'to', 'a') -> ['tiny']
# ('key', 'to', 'a', 'tiny') -> ['door,']
# ('to', 'a', 'tiny', 'door,') -> ['beyond']
# ('a', 'tiny', 'door,', 'beyond') -> ['which']
# ('tiny', 'door,', 'beyond', 'which') -> ['is']
# ('door,', 'beyond', 'which', 'is') -> ['a']
# ('beyond', 'which', 'is', 'a') -> ['garden.']
# ('which', 'is', 'a', 'garden.') -> ['While']
# ('is', 'a', 'garden.', 'While') -> ['pondering']
# ('a', 'garden.', 'While', 'pondering') -> ['how']
# ('garden.', 'While', 'pondering', 'how') -> ['to']
# ('While', 'pondering', 'how', 'to') -> ['fit']
# ('pondering', 'how', 'to', 'fit') -> ['through']
# ('how', 'to', 'fit', 'through') -> ['the']
# ('to', 'fit', 'through', 'the') -> ['door,']
# ('fit', 'through', 'the', 'door,') -> ['she']
# ('through', 'the', 'door,', 'she') -> ['discovers']
# ('the', 'door,', 'she', 'discovers') -> ['a']
# ('door,', 'she', 'discovers', 'a') -> ['bottle']
# ('she', 'discovers', 'a', 'bottle') -> ['labelled']
# ('discovers', 'a', 'bottle', 'labelled') -> ['"Drink']
# ('a', 'bottle', 'labelled', '"Drink') -> ['me".']
# ('bottle', 'labelled', '"Drink', 'me".') -> ['Alice']
# ('labelled', '"Drink', 'me".', 'Alice') -> ['drinks']
# ('"Drink', 'me".', 'Alice', 'drinks') -> ['some']
# ('me".', 'Alice', 'drinks', 'some') -> ['of']
# ('Alice', 'drinks', 'some', 'of') -> ['the']
# ('drinks', 'some', 'of', 'the') -> ["bottle's"]
# ('some', 'of', 'the', "bottle's") -> ['contents,']
# ('of', 'the', "bottle's", 'contents,') -> ['and']
# ('the', "bottle's", 'contents,', 'and') -> ['to']
# ("bottle's", 'contents,', 'and', 'to') -> ['her']
# ('contents,', 'and', 'to', 'her') -> ['astonishment,']
# ('and', 'to', 'her', 'astonishment,') -> ['she']
# ('to', 'her', 'astonishment,', 'she') -> ['shrinks']
# ('her', 'astonishment,', 'she', 'shrinks') -> ['small']
# ('astonishment,', 'she', 'shrinks', 'small') -> ['enough']
# ('she', 'shrinks', 'small', 'enough') -> ['to']
# ('shrinks', 'small', 'enough', 'to') -> ['enter']
# ('small', 'enough', 'to', 'enter') -> ['the']
# ('enough', 'to', 'enter', 'the') -> ['door.']
# ('to', 'enter', 'the', 'door.') -> ['However,']
# ('enter', 'the', 'door.', 'However,') -> ['she']
# ('the', 'door.', 'However,', 'she') -> ['had']
# ('door.', 'However,', 'she', 'had') -> ['left']
# ('However,', 'she', 'had', 'left') -> ['the']
# ('she', 'had', 'left', 'the') -> ['key']
# ('had', 'left', 'the', 'key') -> ['upon']
# ('left', 'the', 'key', 'upon') -> ['the']
# ('the', 'key', 'upon', 'the') -> ['table']
# ('key', 'upon', 'the', 'table') -> ['and']
# ('upon', 'the', 'table', 'and') -> ['cannot']
# ('the', 'table', 'and', 'cannot') -> ['reach']
# ('table', 'and', 'cannot', 'reach') -> ['it.']
# ('and', 'cannot', 'reach', 'it.') -> ['Alice']
# ('cannot', 'reach', 'it.', 'Alice') -> ['then']
# ('reach', 'it.', 'Alice', 'then') -> ['discovers']
# ('it.', 'Alice', 'then', 'discovers') -> ['and']
# ('Alice', 'then', 'discovers', 'and') -> ['eats']
# ('then', 'discovers', 'and', 'eats') -> ['a']
# ('discovers', 'and', 'eats', 'a') -> ['cake']
# ('and', 'eats', 'a', 'cake') -> ['labelled']
# ('eats', 'a', 'cake', 'labelled') -> ['"Eat']
# ('a', 'cake', 'labelled', '"Eat') -> ['me",']
# ('cake', 'labelled', '"Eat', 'me",') -> ['which']
# ('labelled', '"Eat', 'me",', 'which') -> ['causes']
# ('"Eat', 'me",', 'which', 'causes') -> ['her']
# ('me",', 'which', 'causes', 'her') -> ['to']
# ('which', 'causes', 'her', 'to') -> ['grow', 'shrink']
# ('causes', 'her', 'to', 'grow') -> ['to']
# ('her', 'to', 'grow', 'to') -> ['a']
# ('to', 'grow', 'to', 'a') -> ['tremendous']
# ('grow', 'to', 'a', 'tremendous') -> ['size.']
# ('to', 'a', 'tremendous', 'size.') -> ['Unhappy,']
# ('a', 'tremendous', 'size.', 'Unhappy,') -> ['Alice']
# ('tremendous', 'size.', 'Unhappy,', 'Alice') -> ['bursts']
# ('size.', 'Unhappy,', 'Alice', 'bursts') -> ['into']
# ('Unhappy,', 'Alice', 'bursts', 'into') -> ['tears,']
# ('Alice', 'bursts', 'into', 'tears,') -> ['and']
# ('bursts', 'into', 'tears,', 'and') -> ['the']
# ('into', 'tears,', 'and', 'the') -> ['passing']
# ('tears,', 'and', 'the', 'passing') -> ['White']
# ('and', 'the', 'passing', 'White') -> ['Rabbit']
# ('the', 'passing', 'White', 'Rabbit') -> ['flees']
# ('passing', 'White', 'Rabbit', 'flees') -> ['in']
# ('White', 'Rabbit', 'flees', 'in') -> ['a']
# ('Rabbit', 'flees', 'in', 'a') -> ['panic,']
# ('flees', 'in', 'a', 'panic,') -> ['dropping']
# ('in', 'a', 'panic,', 'dropping') -> ['a']
# ('a', 'panic,', 'dropping', 'a') -> ['fan']
# ('panic,', 'dropping', 'a', 'fan') -> ['and']
# ('dropping', 'a', 'fan', 'and') -> ['two']
# ('a', 'fan', 'and', 'two') -> ['gloves.']
# ('fan', 'and', 'two', 'gloves.') -> ['Alice']
# ('and', 'two', 'gloves.', 'Alice') -> ['uses']
# ('two', 'gloves.', 'Alice', 'uses') -> ['the']
# ('gloves.', 'Alice', 'uses', 'the') -> ['fan']
# ('Alice', 'uses', 'the', 'fan') -> ['for']
# ('uses', 'the', 'fan', 'for') -> ['herself,']
# ('the', 'fan', 'for', 'herself,') -> ['which']
# ('fan', 'for', 'herself,', 'which') -> ['causes']
# ('for', 'herself,', 'which', 'causes') -> ['her']
# ('herself,', 'which', 'causes', 'her') -> ['to']
# ('causes', 'her', 'to', 'shrink') -> ['once']
# ('her', 'to', 'shrink', 'once') -> ['more']
# ('to', 'shrink', 'once', 'more') -> ['and']
# ('shrink', 'once', 'more', 'and') -> ['leaves']
# ('once', 'more', 'and', 'leaves') -> ['her']
# ('more', 'and', 'leaves', 'her') -> ['swimming']
# ('and', 'leaves', 'her', 'swimming') -> ['in']
# ('leaves', 'her', 'swimming', 'in') -> ['a']
# ('her', 'swimming', 'in', 'a') -> ['pool']
# ('swimming', 'in', 'a', 'pool') -> ['of']
# ('in', 'a', 'pool', 'of') -> ['her']
# ('a', 'pool', 'of', 'her') -> ['own']
# ('pool', 'of', 'her', 'own') -> ['tears.']
# ('of', 'her', 'own', 'tears.') -> ['Within']
# ('her', 'own', 'tears.', 'Within') -> ['the']
# ('own', 'tears.', 'Within', 'the') -> ['pool,']
# ('tears.', 'Within', 'the', 'pool,') -> ['Alice']
# ('Within', 'the', 'pool,', 'Alice') -> ['meets']
# ('the', 'pool,', 'Alice', 'meets') -> ['various']
# ('pool,', 'Alice', 'meets', 'various') -> ['animals']
# ('Alice', 'meets', 'various', 'animals') -> ['and']
# ('meets', 'various', 'animals', 'and') -> ['birds,']
# ('various', 'animals', 'and', 'birds,') -> ['who']
# ('animals', 'and', 'birds,', 'who') -> ['convene']
# ('and', 'birds,', 'who', 'convene') -> ['on']
# ('birds,', 'who', 'convene', 'on') -> ['a']
# ('who', 'convene', 'on', 'a') -> ['bank']
# ('convene', 'on', 'a', 'bank') -> ['and']
# ('on', 'a', 'bank', 'and') -> ['engage']
# ('a', 'bank', 'and', 'engage') -> ['in']
# ('bank', 'and', 'engage', 'in') -> ['a']
# ('and', 'engage', 'in', 'a') -> ['"Caucus']
# ('engage', 'in', 'a', '"Caucus') -> ['Race"']
# ('in', 'a', '"Caucus', 'Race"') -> ['to']
# ('a', '"Caucus', 'Race"', 'to') -> ['dry']
# ('"Caucus', 'Race"', 'to', 'dry') -> ['themselves.']
# ('Race"', 'to', 'dry', 'themselves.') -> ['Following']
# ('to', 'dry', 'themselves.', 'Following') -> ['the']
# ('dry', 'themselves.', 'Following', 'the') -> ['end']
# ('themselves.', 'Following', 'the', 'end') -> ['of']
# ('Following', 'the', 'end', 'of') -> ['the']
# ('the', 'end', 'of', 'the') -> ['race,']
# ('end', 'of', 'the', 'race,') -> ['Alice']
# ('of', 'the', 'race,', 'Alice') -> ['inadvertently']
# ('the', 'race,', 'Alice', 'inadvertently') -> ['frightens']
# ('race,', 'Alice', 'inadvertently', 'frightens') -> ['the']
# ('Alice', 'inadvertently', 'frightens', 'the') -> ['animals']
# ('inadvertently', 'frightens', 'the', 'animals') -> ['away']
# ('frightens', 'the', 'animals', 'away') -> ['by']
# ('the', 'animals', 'away', 'by') -> ['discussing']
# ('animals', 'away', 'by', 'discussing') -> ['her']
# ('away', 'by', 'discussing', 'her') -> ['cat.']
#
# Generated Sentence:
# White Rabbit
# --------------------------------------------------
#
# Test Case 3 (Empty Sample Text):
# Sample text is empty. Cannot build Markov chain.
